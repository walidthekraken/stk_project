# %%
import numpy as np
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.ppo import MlpPolicy

from imitation.algorithms.adversarial.airl import AIRL
from imitation.data import rollout
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.policies.serialize import load_policy
from imitation.rewards.reward_nets import BasicShapedRewardNet
from imitation.util.networks import RunningNorm
from imitation.util.util import make_vec_env
from imitation.data.types import TrajectoryWithRew
import numpy as np
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.ppo import MlpPolicy

from imitation.algorithms.adversarial.gail import GAIL
from imitation.data import rollout
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.policies.serialize import load_policy
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from imitation.util.util import make_vec_env

from stk_actor.wrappers import PreprocessObservationWrapper

SEED = 42

from stable_baselines3 import PPO, A2C
from stable_baselines3.common.env_util import make_vec_env
import gymnasium as gym
from pystk2_gymnasium import AgentSpec
from bbrl.agents.gymnasium import ParallelGymAgent, make_env
from functools import partial

noob_vec_env = make_vec_env("supertuxkart/flattened_multidiscrete-v0", seed=0, n_envs=21, wrapper_class=lambda x : (PreprocessObservationWrapper(x, ret_dict=False)), env_kwargs={
    'render_mode':None, 'agent':AgentSpec(use_ai=False, name="walid"), 'laps':3,
})

tracks = ['abyss',
 'black_forest',
 'candela_city',
 'cocoa_temple',
 'cornfield_crossing',
 'fortmagma',
 'gran_paradiso_island',
 'hacienda',
 'lighthouse',
 'mines',
 'minigolf',
 'olivermath',
 'ravenbridge_mansion',
 'sandtrack',
 'scotland',
 'snowmountain',
 'snowtuxpeak',
 'stk_enterprise',
 'volcano_island',
 'xr591',
 'zengarden']

for i, venv in enumerate((noob_vec_env.envs)):
    venv.env.default_track = tracks[i%len(tracks)]

# expert = load_policy(
#     "ppo-huggingface",
#     organization="HumanCompatibleAI",
#     env_name="seals-CartPole-v0",
#     venv=noob_vec_env,
# )

# rollouts = rollout.rollout(
#     expert,
#     expert_vec_env,
#     rollout.make_sample_until(min_episodes=60),
#     rng=np.random.default_rng(SEED),
# )
# Out:
# ..:: Antarctica Rendering Engine 2.0 ::..

# %%
from stk_actor.replay_buffer import SACRolloutBuffer
import joblib, torch 

buffer1 = joblib.load('all_tracks_buffer_steps_2mil')
# Out:
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..
# ..:: Antarctica Rendering Engine 2.0 ::..

# %%
import numpy as np
import dataclasses
from typing import Optional, List, Dict, Any, NamedTuple
import torch

def get_trajectories_from_buffer(buffer: SACRolloutBuffer) -> List[TrajectoryWithRew]:
    """
    Convert buffer data into a list of TrajectoryWithRew objects.
    Each trajectory represents a complete episode or episode fragment.
    
    Args:
        buffer: SACRolloutBuffer containing the transitions
        
    Returns:
        List of TrajectoryWithRew objects
    """
    trajectories = []
    current_trajectory = {
        'obs': [],
        'acts': [],
        'rews': [],
        'infos': [],
        'steps': []
    }
    
    # Convert buffer data to numpy for processing
    observations = buffer.observations.numpy()
    actions = np.stack([act.numpy() for act in buffer.actions], axis=1)
    rewards = buffer.rewards.numpy()
    dones = buffer.dones.numpy()
    steps = buffer.steps.numpy()
    next_observations = buffer.next_observations.numpy()
    
    # Process each transition in the buffer
    for i in range(buffer.size):
        # Check if this is the start of a new episode (step == 0)
        if steps[i][0] == 0 and len(current_trajectory['obs']) > 0:
            print(i, steps[i][0],)
            # Convert current trajectory to TrajectoryWithRew and add to list
            current_trajectory['obs'].append(next_observations[i-1])
            trajectories.append(_create_trajectory(
                current_trajectory['obs'],
                current_trajectory['acts'],
                current_trajectory['rews'],
                current_trajectory['infos'],
                True  # Terminal since it's end of episode
            ))
            
            # Reset current trajectory
            current_trajectory = {
                'obs': [],
                'acts': [],
                'rews': [],
                'infos': [],
                'steps': []
            }
            
        # Add current transition to trajectory
        current_trajectory['obs'].append(observations[i])
        current_trajectory['acts'].append(actions[i])
        current_trajectory['rews'].append(rewards[i])
        current_trajectory['infos'].append({
            'step': steps[i],
            'done': False
        })
        current_trajectory['steps'].append(steps[i])
        
        # If this is the last transition or it's done, create a trajectory
        if i == buffer.size - 1:
            
            if len(current_trajectory['obs']) > 0:
                # Add final observation
                if i + 1 < buffer.size:
                    current_trajectory['obs'].append(observations[i + 1])
                else:
                    current_trajectory['obs'].append(observations[i])  # Use last observation if at buffer end
                    
                trajectories.append(_create_trajectory(
                    current_trajectory['obs'],
                    current_trajectory['acts'],
                    current_trajectory['rews'],
                    current_trajectory['infos'],
                    True
                ))
                # Reset current trajectory
                current_trajectory = {
                    'obs': [],
                    'acts': [],
                    'rews': [],
                    'infos': [],
                    'steps': []
                }

    return trajectories

def _create_trajectory(
    observations: List[np.ndarray],
    actions: List[np.ndarray],
    rewards: List[np.ndarray],
    infos: List[Dict[str, Any]],
    terminal: bool
) -> TrajectoryWithRew:
    """
    Create a TrajectoryWithRew object from lists of transitions.
    
    Args:
        observations: List of observations including final observation
        actions: List of actions
        rewards: List of rewards
        infos: List of info dictionaries
        terminal: Whether trajectory ends in terminal state
        
    Returns:
        TrajectoryWithRew object
    """
    return TrajectoryWithRew(
        obs=np.stack(observations),
        acts=np.stack(actions),
        rews=np.stack(rewards).flatten(),
        infos=np.array(infos),
        terminal=terminal
    )

def get_trajectories_by_track(
    buffer: SACRolloutBuffer,
    track_name: str
) -> List[TrajectoryWithRew]:
    """
    Get trajectories for a specific track from the buffer.
    
    Args:
        buffer: SACRolloutBuffer containing the transitions
        track_name: Name of the track to filter trajectories for
        
    Returns:
        List of TrajectoryWithRew objects for the specified track
    """
    track_id = buffer.tracks[track_name]
    track_mask = buffer.track.numpy().flatten() == track_id
    
    # Create a new temporary buffer with only the track data
    temp_buffer = SACRolloutBuffer(
        buffer_size=buffer.buffer_size,
        obs_dim=buffer.obs_dim,
        action_dims=buffer.action_dims
    )
    
    # Copy only the track data
    temp_buffer.observations = buffer.observations[track_mask]
    temp_buffer.actions = [act[track_mask] for act in buffer.actions]
    temp_buffer.rewards = buffer.rewards[track_mask]
    temp_buffer.next_observations = buffer.next_observations[track_mask]
    temp_buffer.dones = buffer.dones[track_mask]
    temp_buffer.steps = buffer.steps[track_mask]
    temp_buffer.track = buffer.track[track_mask]
    temp_buffer.size = track_mask.sum()
    
    return get_trajectories_from_buffer(temp_buffer)

# %%
rollouts = get_trajectories_from_buffer(buffer1)
# Out:
# 2871 0.0
# 8764 0.0
# 11182 0.0
# 13913 0.0
# 16844 0.0
# 19281 0.0
# 22393 0.0
# 25023 0.0
# 26873 0.0
# 29509 0.0
# 31222 0.0
# 32247 0.0
# 35328 0.0
# 38023 0.0
# 40714 0.0
# 43290 0.0
# 45436 0.0
# 48577 0.0
# 53313 0.0
# 56087 0.0
# 57575 0.0
# 59483 0.0
# 63249 0.0
# 64792 0.0
# 66589 0.0
# 68506 0.0
# 70078 0.0
# 72056 0.0
# 73768 0.0
# 75066 0.0
# 76800 0.0
# 78016 0.0
# 78798 0.0
# 80884 0.0
# 82601 0.0
# 84393 0.0
# 85986 0.0
# 87402 0.0
# 89409 0.0
# 92467 0.0
# 94302 0.0
# 95366 0.0
# 97020 0.0
# 100531 0.0
# 101905 0.0
# 103579 0.0
# 105259 0.0
# 106693 0.0
# 108564 0.0
# 110121 0.0
# 111213 0.0
# 112805 0.0
# 113931 0.0
# 114612 0.0
# 116455 0.0
# 118015 0.0
# 119590 0.0
# 121027 0.0
# 122352 0.0
# 124285 0.0
# 127091 0.0
# 128809 0.0
# 129766 0.0
# 132632 0.0
# 138414 0.0
# 140773 0.0
# 143489 0.0
# 146382 0.0
# 148859 0.0
# 152017 0.0
# 154648 0.0
# 156532 0.0
# 159178 0.0
# 160921 0.0
# 161955 0.0
# 165025 0.0
# 167795 0.0
# 170494 0.0
# 173087 0.0
# 175256 0.0
# 178385 0.0
# 183115 0.0
# 185866 0.0
# 187325 0.0
# 189200 0.0
# 193037 0.0
# 194773 0.0
# 196486 0.0
# 198380 0.0
# 199930 0.0
# 201968 0.0
# 203700 0.0
# 204986 0.0
# 206713 0.0
# 207882 0.0
# 208683 0.0
# 210668 0.0
# 212387 0.0
# 214087 0.0
# 215696 0.0
# 217073 0.0
# 219070 0.0
# 222209 0.0
# 224018 0.0
# 225015 0.0
# 226792 0.0
# 230274 0.0
# 231687 0.0
# 233280 0.0
# 235004 0.0
# 236382 0.0
# 238233 0.0
# 239781 0.0
# 240912 0.0
# 242480 0.0
# 243623 0.0
# 244279 0.0
# 246089 0.0
# 247642 0.0
# 249175 0.0
# 250624 0.0
# 251895 0.0
# 253795 0.0
# 256569 0.0
# 258279 0.0
# 259232 0.0
# 262169 0.0
# 268054 0.0
# 270407 0.0
# 273109 0.0
# 276009 0.0
# 278431 0.0
# 281550 0.0
# 284198 0.0
# 286116 0.0
# 288733 0.0
# 290399 0.0
# 291424 0.0
# 294478 0.0
# 297242 0.0
# 299940 0.0
# 302514 0.0
# 304711 0.0
# 307784 0.0
# 312461 0.0
# 315299 0.0
# 316885 0.0
# 318789 0.0
# 322592 0.0
# 324139 0.0
# 325837 0.0
# 327717 0.0
# 329434 0.0
# 331545 0.0
# 333237 0.0
# 334462 0.0
# 336154 0.0
# 337399 0.0
# 338127 0.0
# 340112 0.0
# 341815 0.0
# 343558 0.0
# 345177 0.0
# 346587 0.0
# 348566 0.0
# 351620 0.0
# 353477 0.0
# 354565 0.0
# 356243 0.0
# 359735 0.0
# 361119 0.0
# 362752 0.0
# 364381 0.0
# 365795 0.0
# 367681 0.0
# 369227 0.0
# 370347 0.0
# 371911 0.0
# 373131 0.0
# 373804 0.0
# 375680 0.0
# 377282 0.0
# 378857 0.0
# 380326 0.0
# 381622 0.0
# 383537 0.0
# 386265 0.0
# 388040 0.0
# 389018 0.0
# 391940 0.0
# 397834 0.0
# 400194 0.0
# 402897 0.0
# 405834 0.0
# 408251 0.0
# 411441 0.0
# 414121 0.0
# 415990 0.0
# 418607 0.0
# 420308 0.0
# 421335 0.0
# 424327 0.0
# 427026 0.0
# 429703 0.0
# 432255 0.0
# 434432 0.0
# 437541 0.0
# 442260 0.0
# 445058 0.0
# 446630 0.0
# 448490 0.0
# 452285 0.0
# 453932 0.0
# 455696 0.0
# 457554 0.0
# 459253 0.0
# 461325 0.0
# 463011 0.0
# 464259 0.0
# 466017 0.0
# 467179 0.0
# 467967 0.0
# 469960 0.0
# 471657 0.0
# 473317 0.0
# 474961 0.0
# 476359 0.0
# 478381 0.0
# 481494 0.0
# 483420 0.0
# 484528 0.0
# 486169 0.0
# 489620 0.0
# 491112 0.0
# 492722 0.0
# 494406 0.0
# 495869 0.0
# 497710 0.0
# 499254 0.0
# 500394 0.0
# 501976 0.0
# 503135 0.0
# 503790 0.0
# 505578 0.0
# 507119 0.0
# 508684 0.0
# 510173 0.0
# 511503 0.0
# 513345 0.0
# 516034 0.0
# 517767 0.0
# 518744 0.0
# 521596 0.0
# 527508 0.0
# 529894 0.0
# 532620 0.0
# 535549 0.0
# 537974 0.0
# 541120 0.0
# 543735 0.0
# 545590 0.0
# 548196 0.0
# 549928 0.0
# 550998 0.0
# 554054 0.0
# 556773 0.0
# 559445 0.0
# 562047 0.0
# 564240 0.0
# 567381 0.0
# 572067 0.0
# 574869 0.0
# 576404 0.0
# 578342 0.0
# 582066 0.0
# 583715 0.0
# 585481 0.0
# 587339 0.0
# 588887 0.0
# 590950 0.0
# 592678 0.0
# 593913 0.0
# 595670 0.0
# 596897 0.0
# 597620 0.0
# 599615 0.0
# 601322 0.0
# 603086 0.0
# 604632 0.0
# 606056 0.0
# 608158 0.0
# 611229 0.0
# 613014 0.0
# 614071 0.0
# 615750 0.0
# 619207 0.0
# 620624 0.0
# 622218 0.0
# 623895 0.0
# 625322 0.0
# 627158 0.0
# 628699 0.0
# 629827 0.0
# 631407 0.0
# 632533 0.0
# 633250 0.0
# 635107 0.0
# 636641 0.0
# 638268 0.0
# 639717 0.0
# 641019 0.0
# 642851 0.0
# 645595 0.0
# 647381 0.0

# %%
len(rollouts)
# Out:
# 315

# %%
from stk_actor.agent import UnifiedSACPolicy


net_arch=[512,512,512,512]
activation_fn=torch.nn.SiLU
filename = 'policy_512_512_512_512_SiLU_3_statedict'

learner = PPO(
    env=noob_vec_env,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
    policy_kwargs=dict(net_arch=net_arch, activation_fn=activation_fn,), 
)

action_dims = [space.n for space in noob_vec_env.action_space]
unified_policy = UnifiedSACPolicy(
    noob_vec_env.observation_space, 
    action_dims, 
    net_arch=net_arch, 
    activation_fn=activation_fn
)
unified_policy.load_state_dict(torch.load(filename))
learner.policy.load_state_dict(unified_policy.shared.state_dict())
# Out:
# /var/folders/5b/wsyz4crx22bg_7tpsgbw3tzw0000gn/T/ipykernel_64855/3874999844.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   unified_policy.load_state_dict(torch.load(filename))
# <All keys matched successfully>

# %%
# reward_net = BasicShapedRewardNet(
#     observation_space=noob_vec_env.observation_space,
#     action_space=noob_vec_env.action_space,
#     normalize_input_layer=RunningNorm,
# )
# airl_trainer = AIRL(
#     demonstrations=rollouts,
#     demo_batch_size=2048,
#     gen_replay_buffer_capacity=512,
#     n_disc_updates_per_round=16,
#     venv=noob_vec_env,
#     gen_algo=learner,
#     reward_net=reward_net,
#     allow_variable_horizon=True
# )


reward_net = BasicRewardNet(
    observation_space=noob_vec_env.observation_space,
    action_space=noob_vec_env.action_space,
    normalize_input_layer=RunningNorm,
)
gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=noob_vec_env,
    gen_algo=learner,
    reward_net=reward_net,
    allow_variable_horizon=True,
)
# Out:
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html for more information.

# %%
noob_vec_env.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner, noob_vec_env, 1, return_episode_rewards=True,
)

# %%
print("mean reward before training:", np.mean(learner_rewards_before_training))

# %%
gail_trainer.train(43008 * 10)  # Train for 2_000_000 steps to match expert.
# Out:
# round:   0%|          | 0/10 [00:00<?, ?it/s]
# ------------------------------------------
# | raw/                        |          |
# |    gen/rollout/ep_len_mean  | 1.49e+03 |
# |    gen/rollout/ep_rew_mean  | 8.76     |
# |    gen/time/fps             | 86       |
# |    gen/time/iterations      | 1        |
# |    gen/time/time_elapsed    | 496      |
# |    gen/time/total_timesteps | 43008    |
# ------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.501    |
# |    disc/disc_acc_expert             | 0.00195  |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.696    |
# |    disc/disc_proportion_expert_pred | 0.000977 |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.502    |
# |    disc/disc_acc_expert             | 0.00391  |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.684    |
# |    disc/disc_proportion_expert_pred | 0.00195  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.508    |
# |    disc/disc_acc_expert             | 0.0166   |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.671    |
# |    disc/disc_proportion_expert_pred | 0.0083   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.523    |
# |    disc/disc_acc_expert             | 0.0469   |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.659    |
# |    disc/disc_proportion_expert_pred | 0.0234   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.56     |
# |    disc/disc_acc_expert             | 0.12     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.0601   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.615    |
# |    disc/disc_acc_expert             | 0.23     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.635    |
# |    disc/disc_proportion_expert_pred | 0.115    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.668    |
# |    disc/disc_acc_expert             | 0.337    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.624    |
# |    disc/disc_proportion_expert_pred | 0.168    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.738    |
# |    disc/disc_acc_expert             | 0.476    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.612    |
# |    disc/disc_proportion_expert_pred | 0.238    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.577    |
# |    disc/disc_acc_expert             | 0.154    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0.077    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 1.49e+03 |
# |    gen/rollout/ep_rew_mean          | 8.76     |
# |    gen/time/fps                     | 86       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 496      |
# |    gen/time/total_timesteps         | 4.3e+04  |
# |    gen/train/approx_kl              | 173      |
# |    gen/train/clip_fraction          | 0.905    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -0.257   |
# |    gen/train/explained_variance     | -0.0601  |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.771    |
# |    gen/train/n_updates              | 5        |
# |    gen/train/policy_gradient_loss   | 0.222    |
# |    gen/train/value_loss             | 45.8     |
# --------------------------------------------------
# round:  10%|█         | 1/10 [08:51<1:19:47, 531.91s/it]
# --------------------------------------------------
# | raw/                               |           |
# |    gen/rollout/ep_len_mean         | 1.49e+03  |
# |    gen/rollout/ep_rew_mean         | 21.6      |
# |    gen/rollout/ep_rew_wrapped_mean | 40.6      |
# |    gen/time/fps                    | 96        |
# |    gen/time/iterations             | 1         |
# |    gen/time/time_elapsed           | 444       |
# |    gen/time/total_timesteps        | 86016     |
# |    gen/train/approx_kl             | 172.63435 |
# |    gen/train/clip_fraction         | 0.905     |
# |    gen/train/clip_range            | 0.1       |
# |    gen/train/entropy_loss          | -0.257    |
# |    gen/train/explained_variance    | -0.0601   |
# |    gen/train/learning_rate         | 0.0005    |
# |    gen/train/loss                  | 0.771     |
# |    gen/train/n_updates             | 5         |
# |    gen/train/policy_gradient_loss  | 0.222     |
# |    gen/train/value_loss            | 45.8      |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.785    |
# |    disc/disc_acc_expert             | 0.57     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0.285    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.812    |
# |    disc/disc_acc_expert             | 0.625    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.638    |
# |    disc/disc_proportion_expert_pred | 0.312    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.842    |
# |    disc/disc_acc_expert             | 0.684    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.627    |
# |    disc/disc_proportion_expert_pred | 0.342    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.854    |
# |    disc/disc_acc_expert             | 0.707    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.618    |
# |    disc/disc_proportion_expert_pred | 0.354    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.876    |
# |    disc/disc_acc_expert             | 0.752    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.608    |
# |    disc/disc_proportion_expert_pred | 0.376    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.907    |
# |    disc/disc_acc_expert             | 0.813    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.595    |
# |    disc/disc_proportion_expert_pred | 0.407    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.92     |
# |    disc/disc_acc_expert             | 0.84     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.585    |
# |    disc/disc_proportion_expert_pred | 0.42     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.934    |
# |    disc/disc_acc_expert             | 0.868    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.572    |
# |    disc/disc_proportion_expert_pred | 0.434    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.866    |
# |    disc/disc_acc_expert             | 0.732    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.611    |
# |    disc/disc_proportion_expert_pred | 0.366    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 1.49e+03 |
# |    gen/rollout/ep_rew_mean          | 21.6     |
# |    gen/rollout/ep_rew_wrapped_mean  | 40.6     |
# |    gen/time/fps                     | 96       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 444      |
# |    gen/time/total_timesteps         | 8.6e+04  |
# |    gen/train/approx_kl              | 362      |
# |    gen/train/clip_fraction          | 0.731    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -0.00271 |
# |    gen/train/explained_variance     | -0.279   |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0381   |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.0151  |
# |    gen/train/value_loss             | 3.41     |
# --------------------------------------------------
# round:  20%|██        | 2/10 [16:47<1:06:28, 498.60s/it]
# --------------------------------------------------
# | raw/                               |           |
# |    gen/rollout/ep_len_mean         | 1.5e+03   |
# |    gen/rollout/ep_rew_mean         | -51.7     |
# |    gen/rollout/ep_rew_wrapped_mean | 328       |
# |    gen/time/fps                    | 88        |
# |    gen/time/iterations             | 1         |
# |    gen/time/time_elapsed           | 485       |
# |    gen/time/total_timesteps        | 129024    |
# |    gen/train/approx_kl             | 362.29013 |
# |    gen/train/clip_fraction         | 0.731     |
# |    gen/train/clip_range            | 0.1       |
# |    gen/train/entropy_loss          | -0.00271  |
# |    gen/train/explained_variance    | -0.279    |
# |    gen/train/learning_rate         | 0.0005    |
# |    gen/train/loss                  | 0.0381    |
# |    gen/train/n_updates             | 10        |
# |    gen/train/policy_gradient_loss  | -0.0151   |
# |    gen/train/value_loss            | 3.41      |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.934    |
# |    disc/disc_acc_expert             | 0.868    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.594    |
# |    disc/disc_proportion_expert_pred | 0.434    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.953    |
# |    disc/disc_acc_expert             | 0.906    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.579    |
# |    disc/disc_proportion_expert_pred | 0.453    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.943    |
# |    disc/disc_acc_expert             | 0.886    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.678    |
# |    disc/disc_loss                   | 0.567    |
# |    disc/disc_proportion_expert_pred | 0.443    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.947    |
# |    disc/disc_acc_expert             | 0.894    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.676    |
# |    disc/disc_loss                   | 0.555    |
# |    disc/disc_proportion_expert_pred | 0.447    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.958    |
# |    disc/disc_acc_expert             | 0.915    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.539    |
# |    disc/disc_proportion_expert_pred | 0.458    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.955    |
# |    disc/disc_acc_expert             | 0.909    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.668    |
# |    disc/disc_loss                   | 0.524    |
# |    disc/disc_proportion_expert_pred | 0.455    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.96     |
# |    disc/disc_acc_expert             | 0.92     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.665    |
# |    disc/disc_loss                   | 0.512    |
# |    disc/disc_proportion_expert_pred | 0.46     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.956    |
# |    disc/disc_acc_expert             | 0.912    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.66     |
# |    disc/disc_loss                   | 0.501    |
# |    disc/disc_proportion_expert_pred | 0.456    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.951     |
# |    disc/disc_acc_expert             | 0.901     |
# |    disc/disc_acc_gen                | 1         |
# |    disc/disc_entropy                | 0.673     |
# |    disc/disc_loss                   | 0.546     |
# |    disc/disc_proportion_expert_pred | 0.451     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 3         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 1.5e+03   |
# |    gen/rollout/ep_rew_mean          | -51.7     |
# |    gen/rollout/ep_rew_wrapped_mean  | 328       |
# |    gen/time/fps                     | 88        |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 485       |
# |    gen/time/total_timesteps         | 1.29e+05  |
# |    gen/train/approx_kl              | 0.00317   |
# |    gen/train/clip_fraction          | 6.05e-05  |
# |    gen/train/clip_range             | 0.1       |
# |    gen/train/entropy_loss           | -7.91e-07 |
# |    gen/train/explained_variance     | 0.458     |
# |    gen/train/learning_rate          | 0.0005    |
# |    gen/train/loss                   | 0.0192    |
# |    gen/train/n_updates              | 15        |
# |    gen/train/policy_gradient_loss   | -4.77e-06 |
# |    gen/train/value_loss             | 0.273     |
# ---------------------------------------------------
# round:  30%|███       | 3/10 [25:26<59:14, 507.83s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 1.5e+03     |
# |    gen/rollout/ep_rew_mean         | -70.9       |
# |    gen/rollout/ep_rew_wrapped_mean | 619         |
# |    gen/time/fps                    | 92          |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 462         |
# |    gen/time/total_timesteps        | 172032      |
# |    gen/train/approx_kl             | 0.003171274 |
# |    gen/train/clip_fraction         | 6.05e-05    |
# |    gen/train/clip_range            | 0.1         |
# |    gen/train/entropy_loss          | -7.91e-07   |
# |    gen/train/explained_variance    | 0.458       |
# |    gen/train/learning_rate         | 0.0005      |
# |    gen/train/loss                  | 0.0192      |
# |    gen/train/n_updates             | 15          |
# |    gen/train/policy_gradient_loss  | -4.77e-06   |
# |    gen/train/value_loss            | 0.273       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.964    |
# |    disc/disc_acc_expert             | 0.929    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.665    |
# |    disc/disc_loss                   | 0.531    |
# |    disc/disc_proportion_expert_pred | 0.464    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.954    |
# |    disc/disc_acc_expert             | 0.908    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.659    |
# |    disc/disc_loss                   | 0.511    |
# |    disc/disc_proportion_expert_pred | 0.454    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.964    |
# |    disc/disc_acc_expert             | 0.928    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.651    |
# |    disc/disc_loss                   | 0.485    |
# |    disc/disc_proportion_expert_pred | 0.464    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.963    |
# |    disc/disc_acc_expert             | 0.927    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.646    |
# |    disc/disc_loss                   | 0.467    |
# |    disc/disc_proportion_expert_pred | 0.463    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.963    |
# |    disc/disc_acc_expert             | 0.927    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.637    |
# |    disc/disc_loss                   | 0.447    |
# |    disc/disc_proportion_expert_pred | 0.463    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.968    |
# |    disc/disc_acc_expert             | 0.936    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.63     |
# |    disc/disc_loss                   | 0.43     |
# |    disc/disc_proportion_expert_pred | 0.468    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.963    |
# |    disc/disc_acc_expert             | 0.926    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.618    |
# |    disc/disc_loss                   | 0.406    |
# |    disc/disc_proportion_expert_pred | 0.463    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.964    |
# |    disc/disc_acc_expert             | 0.928    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.611    |
# |    disc/disc_loss                   | 0.395    |
# |    disc/disc_proportion_expert_pred | 0.464    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.963     |
# |    disc/disc_acc_expert             | 0.926     |
# |    disc/disc_acc_gen                | 1         |
# |    disc/disc_entropy                | 0.639     |
# |    disc/disc_loss                   | 0.459     |
# |    disc/disc_proportion_expert_pred | 0.463     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 4         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 1.5e+03   |
# |    gen/rollout/ep_rew_mean          | -70.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 619       |
# |    gen/time/fps                     | 92        |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 462       |
# |    gen/time/total_timesteps         | 1.72e+05  |
# |    gen/train/approx_kl              | 0         |
# |    gen/train/clip_fraction          | 0         |
# |    gen/train/clip_range             | 0.1       |
# |    gen/train/entropy_loss           | -1.81e-23 |
# |    gen/train/explained_variance     | 0.712     |
# |    gen/train/learning_rate          | 0.0005    |
# |    gen/train/loss                   | 0.00285   |
# |    gen/train/n_updates              | 20        |
# |    gen/train/policy_gradient_loss   | 5.13e-09  |
# |    gen/train/value_loss             | 0.0478    |
# ---------------------------------------------------
# round:  40%|████      | 4/10 [33:39<50:13, 502.27s/it]
# --------------------------------------------------
# | raw/                               |           |
# |    gen/rollout/ep_len_mean         | 1.5e+03   |
# |    gen/rollout/ep_rew_mean         | -104      |
# |    gen/rollout/ep_rew_wrapped_mean | 693       |
# |    gen/time/fps                    | 70        |
# |    gen/time/iterations             | 1         |
# |    gen/time/time_elapsed           | 608       |
# |    gen/time/total_timesteps        | 215040    |
# |    gen/train/approx_kl             | 0.0       |
# |    gen/train/clip_fraction         | 0         |
# |    gen/train/clip_range            | 0.1       |
# |    gen/train/entropy_loss          | -1.81e-23 |
# |    gen/train/explained_variance    | 0.712     |
# |    gen/train/learning_rate         | 0.0005    |
# |    gen/train/loss                  | 0.00285   |
# |    gen/train/n_updates             | 20        |
# |    gen/train/policy_gradient_loss  | 5.13e-09  |
# |    gen/train/value_loss            | 0.0478    |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.968    |
# |    disc/disc_acc_expert             | 0.936    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.592    |
# |    disc/disc_loss                   | 0.363    |
# |    disc/disc_proportion_expert_pred | 0.468    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.97     |
# |    disc/disc_acc_expert             | 0.939    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.586    |
# |    disc/disc_loss                   | 0.354    |
# |    disc/disc_proportion_expert_pred | 0.47     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.971    |
# |    disc/disc_acc_expert             | 0.942    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.574    |
# |    disc/disc_loss                   | 0.34     |
# |    disc/disc_proportion_expert_pred | 0.471    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.966    |
# |    disc/disc_acc_expert             | 0.933    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.564    |
# |    disc/disc_loss                   | 0.331    |
# |    disc/disc_proportion_expert_pred | 0.466    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.976    |
# |    disc/disc_acc_expert             | 0.952    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.545    |
# |    disc/disc_loss                   | 0.304    |
# |    disc/disc_proportion_expert_pred | 0.476    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.977    |
# |    disc/disc_acc_expert             | 0.953    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.533    |
# |    disc/disc_loss                   | 0.291    |
# |    disc/disc_proportion_expert_pred | 0.477    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.978    |
# |    disc/disc_acc_expert             | 0.955    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.523    |
# |    disc/disc_loss                   | 0.279    |
# |    disc/disc_proportion_expert_pred | 0.478    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.98     |
# |    disc/disc_acc_expert             | 0.96     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.507    |
# |    disc/disc_loss                   | 0.263    |
# |    disc/disc_proportion_expert_pred | 0.48     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.973     |
# |    disc/disc_acc_expert             | 0.946     |
# |    disc/disc_acc_gen                | 1         |
# |    disc/disc_entropy                | 0.553     |
# |    disc/disc_loss                   | 0.316     |
# |    disc/disc_proportion_expert_pred | 0.473     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 5         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 1.5e+03   |
# |    gen/rollout/ep_rew_mean          | -104      |
# |    gen/rollout/ep_rew_wrapped_mean  | 693       |
# |    gen/time/fps                     | 70        |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 608       |
# |    gen/time/total_timesteps         | 2.15e+05  |
# |    gen/train/approx_kl              | 0.000436  |
# |    gen/train/clip_fraction          | 4.65e-05  |
# |    gen/train/clip_range             | 0.1       |
# |    gen/train/entropy_loss           | -5.34e-06 |
# |    gen/train/explained_variance     | 0.776     |
# |    gen/train/learning_rate          | 0.0005    |
# |    gen/train/loss                   | 0.00126   |
# |    gen/train/n_updates              | 25        |
# |    gen/train/policy_gradient_loss   | 4.3e-06   |
# |    gen/train/value_loss             | 0.0268    |
# ---------------------------------------------------
# round:  50%|█████     | 5/10 [44:19<45:59, 551.92s/it]
# ------------------------------------------------------
# | raw/                               |               |
# |    gen/rollout/ep_len_mean         | 1.5e+03       |
# |    gen/rollout/ep_rew_mean         | -122          |
# |    gen/rollout/ep_rew_wrapped_mean | 815           |
# |    gen/time/fps                    | 70            |
# |    gen/time/iterations             | 1             |
# |    gen/time/time_elapsed           | 613           |
# |    gen/time/total_timesteps        | 258048        |
# |    gen/train/approx_kl             | 0.00043601033 |
# |    gen/train/clip_fraction         | 4.65e-05      |
# |    gen/train/clip_range            | 0.1           |
# |    gen/train/entropy_loss          | -5.34e-06     |
# |    gen/train/explained_variance    | 0.776         |
# |    gen/train/learning_rate         | 0.0005        |
# |    gen/train/loss                  | 0.00126       |
# |    gen/train/n_updates             | 25            |
# |    gen/train/policy_gradient_loss  | 4.3e-06       |
# |    gen/train/value_loss            | 0.0268        |
# ------------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.976    |
# |    disc/disc_acc_expert             | 0.952    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.54     |
# |    disc/disc_loss                   | 0.316    |
# |    disc/disc_proportion_expert_pred | 0.476    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.981    |
# |    disc/disc_acc_expert             | 0.963    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.529    |
# |    disc/disc_loss                   | 0.301    |
# |    disc/disc_proportion_expert_pred | 0.481    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.976    |
# |    disc/disc_acc_expert             | 0.951    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.519    |
# |    disc/disc_loss                   | 0.291    |
# |    disc/disc_proportion_expert_pred | 0.476    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.98     |
# |    disc/disc_acc_expert             | 0.96     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.502    |
# |    disc/disc_loss                   | 0.272    |
# |    disc/disc_proportion_expert_pred | 0.48     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.985    |
# |    disc/disc_acc_expert             | 0.971    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.487    |
# |    disc/disc_loss                   | 0.254    |
# |    disc/disc_proportion_expert_pred | 0.485    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.985    |
# |    disc/disc_acc_expert             | 0.97     |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.473    |
# |    disc/disc_loss                   | 0.24     |
# |    disc/disc_proportion_expert_pred | 0.485    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.986    |
# |    disc/disc_acc_expert             | 0.972    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.462    |
# |    disc/disc_loss                   | 0.228    |
# |    disc/disc_proportion_expert_pred | 0.486    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.984    |
# |    disc/disc_acc_expert             | 0.968    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.445    |
# |    disc/disc_loss                   | 0.216    |
# |    disc/disc_proportion_expert_pred | 0.484    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.982     |
# |    disc/disc_acc_expert             | 0.963     |
# |    disc/disc_acc_gen                | 1         |
# |    disc/disc_entropy                | 0.495     |
# |    disc/disc_loss                   | 0.265     |
# |    disc/disc_proportion_expert_pred | 0.482     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 6         |
# |    disc/n_expert                    | 1.02e+03  |
# |    disc/n_generated                 | 1.02e+03  |
# |    gen/rollout/ep_len_mean          | 1.5e+03   |
# |    gen/rollout/ep_rew_mean          | -122      |
# |    gen/rollout/ep_rew_wrapped_mean  | 815       |
# |    gen/time/fps                     | 70        |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 613       |
# |    gen/time/total_timesteps         | 2.58e+05  |
# |    gen/train/approx_kl              | 0         |
# |    gen/train/clip_fraction          | 0         |
# |    gen/train/clip_range             | 0.1       |
# |    gen/train/entropy_loss           | -1.22e-38 |
# |    gen/train/explained_variance     | 0.838     |
# |    gen/train/learning_rate          | 0.0005    |
# |    gen/train/loss                   | 0.00243   |
# |    gen/train/n_updates              | 30        |
# |    gen/train/policy_gradient_loss   | 9.53e-11  |
# |    gen/train/value_loss             | 0.0679    |
# ---------------------------------------------------
# round:  60%|██████    | 6/10 [55:05<38:54, 583.72s/it]
# --------------------------------------------------
# | raw/                               |           |
# |    gen/rollout/ep_len_mean         | 1.5e+03   |
# |    gen/rollout/ep_rew_mean         | -124      |
# |    gen/rollout/ep_rew_wrapped_mean | 740       |
# |    gen/time/fps                    | 71        |
# |    gen/time/iterations             | 1         |
# |    gen/time/time_elapsed           | 599       |
# |    gen/time/total_timesteps        | 301056    |
# |    gen/train/approx_kl             | 0.0       |
# |    gen/train/clip_fraction         | 0         |
# |    gen/train/clip_range            | 0.1       |
# |    gen/train/entropy_loss          | -1.22e-38 |
# |    gen/train/explained_variance    | 0.838     |
# |    gen/train/learning_rate         | 0.0005    |
# |    gen/train/loss                  | 0.00243   |
# |    gen/train/n_updates             | 30        |
# |    gen/train/policy_gradient_loss  | 9.53e-11  |
# ...
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/imitation/algorithms/adversarial/common.py:454, in AdversarialTrainer.train(self, total_timesteps, callback)
#     448 assert n_rounds >= 1, (
#     449     "No updates (need at least "
#     450     f"{self.gen_train_timesteps} timesteps, have only "
#     451     f"total_timesteps={total_timesteps})!"
#     452 )
#     453 for r in tqdm.tqdm(range(0, n_rounds), desc="round"):
# --> 454     self.train_gen(self.gen_train_timesteps)
#     455     for _ in range(self.n_disc_updates_per_round):
#     456         with networks.training(self.reward_train):
#     457             # switch to training mode (affects dropout, normalization)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/imitation/algorithms/adversarial/common.py:414, in AdversarialTrainer.train_gen(self, total_timesteps, learn_kwargs)
#     411     learn_kwargs = {}
#     413 with self.logger.accumulate_means("gen"):
# --> 414     self.gen_algo.learn(
#     415         total_timesteps=total_timesteps,
#     416         reset_num_timesteps=False,
#     417         callback=self.gen_callback,
#     418         **learn_kwargs,
#     419     )
#     420     self._global_step += 1
#     422 gen_trajs, ep_lens = self.venv_buffering.pop_trajectories()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:218, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     213     else:
#     214         # Otherwise, clip the actions to avoid out of bound error
#     215         # as we are sampling from an unbounded Gaussian distribution
#     216         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 218 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     220 self.num_timesteps += env.num_envs
#     222 # Give access to local variables
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:207, in VecEnv.step(self, actions)
#     200 """
#     201 Step the environments with the given action
#     202
#     203 :param actions: the action
#     204 :return: observation, reward, done, information
#     205 """
#     206 self.step_async(actions)
# --> 207 return self.step_wait()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/imitation/rewards/reward_wrapper.py:93, in RewardVecEnvWrapper.step_wait(self)
#      92 def step_wait(self):
# ---> 93     obs, old_rews, dones, infos = self.venv.step_wait()
#      95     # The vecenvs automatically reset the underlying environments once they
#      96     # encounter a `done`, in which case the last observation corresponding to
#      97     # the `done` is dropped. We're going to pull it back out of the info dict!
#      98     obs_fixed = []
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/imitation/data/wrappers.py:73, in BufferingWrapper.step_wait(self)
#      71 assert self._saved_acts is not None
#      72 acts, self._saved_acts = self._saved_acts, None
# ---> 73 obs, rews, dones, infos = self.venv.step_wait()
#      75 self.n_transitions += self.num_envs
#      76 self._timesteps += 1
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/gymnasium/core.py:522, in ObservationWrapper.step(self, action)
#     518 def step(
#     519     self, action: ActType
#     520 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     521     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 522     observation, reward, terminated, truncated, info = self.env.step(action)
#     523     return self.observation(observation), reward, terminated, truncated, info
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/definitions.py:63, in ActionObservationWrapper.step(self, action)
#      60 """Modifies the :attr:`env` after calling :meth:`step` using
#      61 :meth:`self.observation` on the returned observations."""
#      62 action = self.action(action)
# ---> 63 observation, reward, terminated, truncated, info = self.env.step(action)
#      64 return self.observation(observation), reward, terminated, truncated, info
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/definitions.py:63, in ActionObservationWrapper.step(self, action)
#      60 """Modifies the :attr:`env` after calling :meth:`step` using
#      61 :meth:`self.observation` on the returned observations."""
#      62 action = self.action(action)
# ---> 63 observation, reward, terminated, truncated, info = self.env.step(action)
#      64 return self.observation(observation), reward, terminated, truncated, info
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/gymnasium/core.py:522, in ObservationWrapper.step(self, action)
#     518 def step(
#     519     self, action: ActType
#     520 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     521     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 522     observation, reward, terminated, truncated, info = self.env.step(action)
#     523     return self.observation(observation), reward, terminated, truncated, info
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/gymnasium/core.py:522, in ObservationWrapper.step(self, action)
#     518 def step(
#     519     self, action: ActType
#     520 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     521     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 522     observation, reward, terminated, truncated, info = self.env.step(action)
#     523     return self.observation(observation), reward, terminated, truncated, info
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/envs.py:479, in STKRaceEnv.step(self, action)
#     475     self.race_step(get_action(action))
#     477 self.world_update()
# --> 479 obs, reward, terminated, info = self.get_state(self.kart_ix, self.agent.use_ai)
#     481 return (obs, reward, terminated, False, info)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/envs.py:249, in BaseSTKRaceEnv.get_state(self, kart_ix, use_ai)
#     246 terminated = kart.has_finished_race
#     248 # Get the observation and update the world state
# --> 249 obs = self.get_observation(kart_ix, use_ai)
#     251 d_t = max(0, kart.overall_distance)
#     252 f_t = 1 if terminated else 0
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/envs.py:391, in BaseSTKRaceEnv.get_observation(self, kart_ix, use_ai)
#     345     action = self._process.get_kart_action(kart_ix)
#     346     obs = {
#     347         "action": {
#     348             "acceleration": np.array([action.acceleration], dtype=np.float32),
#    (...)
#     355         }
#     356     }
#     358 return {
#     359     **obs,
#     360     # World properties
#     361     "phase": Phase.from_stk(self.world.phase).value,
#     362     "aux_ticks": np.array([self.world.aux_ticks], dtype=np.float32),
#     363     # Kart properties
#     364     "powerup": kart.powerup.num,
#     365     "attachment": kart.attachment.type.value,
#     366     "attachment_time_left": np.array(
#     367         [kart.attachment.time_left], dtype=np.float32
#     368     ),
#     369     "max_steer_angle": np.array([kart.max_steer_angle], dtype=np.float32),
#     370     "energy": np.array([kart.energy], dtype=np.float32),
#     371     "skeed_factor": np.array([kart.skeed_factor], dtype=np.float32),
#     372     "shield_time": np.array([kart.shield_time], dtype=np.float32),
#     373     "jumping": 1 if kart.jumping else 0,
#     374     # Kart physics (from the kart point view)
#     375     "distance_down_track": np.array(
#     376         [kart.distance_down_track], dtype=np.float32
#     377     ),
#     378     "velocity": kart.velocity_lc,
#     379     "front": kartview(kart.front),
#     380     # path center
#     381     "center_path_distance": np.array([center_path_distance], dtype=np.float32),
#     382     "center_path": np.array(x_orth),
#     383     # Items (kart point of view)
#     384     "items_position": tuple(items_position),
#     385     "items_type": tuple(items_type),
#     386     # Other karts (kart point of view)
#     387     "karts_position": tuple(karts_position),
#     388     # Paths
#     389     "paths_distance": tuple(iterate_from(self.track.path_distance, path_ix)),
#     390     "paths_width": tuple(iterate_from(self.track.path_width, path_ix)),
# --> 391     "paths_start": tuple(
#     392         kartview(x[0]) for x in iterate_from(self.track.path_nodes, path_ix)
#     393     ),
#     394     "paths_end": tuple(
#     395         kartview(x[1]) for x in iterate_from(self.track.path_nodes, path_ix)
#     396     ),
#     397 }
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/envs.py:392, in <genexpr>(.0)
#     345     action = self._process.get_kart_action(kart_ix)
#     346     obs = {
#     347         "action": {
#     348             "acceleration": np.array([action.acceleration], dtype=np.float32),
#    (...)
#     355         }
#     356     }
#     358 return {
#     359     **obs,
#     360     # World properties
#     361     "phase": Phase.from_stk(self.world.phase).value,
#     362     "aux_ticks": np.array([self.world.aux_ticks], dtype=np.float32),
#     363     # Kart properties
#     364     "powerup": kart.powerup.num,
#     365     "attachment": kart.attachment.type.value,
#     366     "attachment_time_left": np.array(
#     367         [kart.attachment.time_left], dtype=np.float32
#     368     ),
#     369     "max_steer_angle": np.array([kart.max_steer_angle], dtype=np.float32),
#     370     "energy": np.array([kart.energy], dtype=np.float32),
#     371     "skeed_factor": np.array([kart.skeed_factor], dtype=np.float32),
#     372     "shield_time": np.array([kart.shield_time], dtype=np.float32),
#     373     "jumping": 1 if kart.jumping else 0,
#     374     # Kart physics (from the kart point view)
#     375     "distance_down_track": np.array(
#     376         [kart.distance_down_track], dtype=np.float32
#     377     ),
#     378     "velocity": kart.velocity_lc,
#     379     "front": kartview(kart.front),
#     380     # path center
#     381     "center_path_distance": np.array([center_path_distance], dtype=np.float32),
#     382     "center_path": np.array(x_orth),
#     383     # Items (kart point of view)
#     384     "items_position": tuple(items_position),
#     385     "items_type": tuple(items_type),
#     386     # Other karts (kart point of view)
#     387     "karts_position": tuple(karts_position),
#     388     # Paths
#     389     "paths_distance": tuple(iterate_from(self.track.path_distance, path_ix)),
#     390     "paths_width": tuple(iterate_from(self.track.path_width, path_ix)),
#     391     "paths_start": tuple(
# --> 392         kartview(x[0]) for x in iterate_from(self.track.path_nodes, path_ix)
#     393     ),
#     394     "paths_end": tuple(
#     395         kartview(x[1]) for x in iterate_from(self.track.path_nodes, path_ix)
#     396     ),
#     397 }
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/envs.py:277, in BaseSTKRaceEnv.get_observation.<locals>.kartview(x)
#     272 def kartview(x):
#     273     """Returns a vector in the kart frame
#     274
#     275     X right, Y up, Z forwards
#     276     """
# --> 277     return rotate(x - kart.location, kart.rotation)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bbrl/lib/python3.10/site-packages/pystk2_gymnasium/utils.py:34, in rotate(v, q)
#      31 x, y, z = v
#      32 qw, qx, qy, qz = q
# ---> 34 return np.array(
#      35     [
#      36         x * (qx * qx + qw * qw - qy * qy - qz * qz)
#      37         + y * (2 * qx * qy - 2 * qw * qz)
#      38         + z * (2 * qx * qz + 2 * qw * qy),
#      39         x * (2 * qw * qz + 2 * qx * qy)
#      40         + y * (qw * qw - qx * qx + qy * qy - qz * qz)
#      41         + z * (-2 * qw * qx + 2 * qy * qz),
#      42         x * (-2 * qw * qy + 2 * qx * qz)
#      43         + y * (2 * qw * qx + 2 * qy * qz)
#      44         + z * (qw * qw - qx * qx - qy * qy + qz * qz),
#      45     ],
#      46     dtype=v.dtype,
#      47 )
#
# KeyboardInterrupt:

# %%
torch.save(learner.policy.state_dict(),'airl_policy_512_512_512_512_SiLU_statedict')

# %%
learner.policy
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=154, out_features=512, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): SiLU()
#       (4): Linear(in_features=512, out_features=512, bias=True)
#       (5): SiLU()
#       (6): Linear(in_features=512, out_features=512, bias=True)
#       (7): SiLU()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=154, out_features=512, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): SiLU()
#       (4): Linear(in_features=512, out_features=512, bias=True)
#       (5): SiLU()
#       (6): Linear(in_features=512, out_features=512, bias=True)
#       (7): SiLU()
#     )
#   )
#   (action_net): Linear(in_features=512, out_features=22, bias=True)
#   (value_net): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
env.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True,
)

print("mean reward after training:", np.mean(learner_rewards_after_training))
